# %% [markdown]
# ### Check Python Version

# %%
import platform
print(platform.python_version())
# Out:
# 3.11.12

# %% [markdown]
# ### Print

# %%
print ("hello Python")
# Out:
# hello Python

# %%
name = input("What is your name?")
# Out:
# What is your name?Yugo

# %%
print("Hello ", name)
# Out:
# Hello  Yugo

# %%
print("Berapa nilai 5 + 7 = 12")
# Out:
# Berapa nilai 5 + 7 = 12

# %%
print("Berapa nilai 5 + 7 =", 5+7)
# Out:
# Berapa nilai 5 + 7 = 12

# %% [markdown]
# ### Basic Ops

# %%
a = 5
b = 70
c = a * b

# %%
print("Berapa nilai", a , "*", b, "=", c)
# Out:
# Berapa nilai 5 * 70 = 350

# %%
print(f"Berapa nilai {a} * {b} = {c}")
# Out:
# Berapa nilai 5 * 70 = 350

# %%
(4+8*20-2)**2
# Out:
# 26244

# %%
print(10 > 3)
# Out:
# True

# %%
10 > 10.5
# Out:
# False

# %% [markdown]
# ### Type

# %%
type(15)
# Out:
# int

# %%
type("15")
# Out:
# str

# %%
type(15.1)
# Out:
# float

# %%
type([15])
# Out:
# list

# %% [markdown]
# ### Data Type

# %%
{'madu': 'manis', 'pisang': [15], 'buah': {'madu': 'manis'}}
# Out:
# {'madu': 'manis', 'pisang': [15], 'buah': {'madu': 'manis'}}

# %%
kemenkeu = [["DJP Lap. Banteng", "DJP BSD"], "DJA"]
KSSK = ["BI", kemenkeu, "OJK", "LPS"]
KSSK
# Out:
# ['BI', [['DJP Lap. Banteng', 'DJP BSD'], 'DJA'], 'OJK', 'LPS']

# %%
KSSK[0]
# Out:
# 'BI'

# %%
KSSK[2]
# Out:
# 'OJK'

# %%
print(KSSK[1])
print(KSSK[1][0])
print(KSSK[1][0][1])
# Out:
# [['DJP Lap. Banteng', 'DJP BSD'], 'DJA']
# ['DJP Lap. Banteng', 'DJP BSD']
# DJP BSD

# %%
Car = {'Brand' : 'Toyota',
		'Model' : 'Innova Reborn',
        'Price': 100000
}
print(Car)
print(Car['Brand'])
# Out:
# {'Brand': 'Toyota', 'Model': 'Innova Reborn', 'Price': 100000}
# Toyota

# %%
Student = { 'Name' : 'Bob',
			'Grades' : {
				'Math' : 80,
				'Biology' : 70,
				'Physics': 60
				}
		}
print(Student)
print(Student['Grades']['Math'])
# Out:
# {'Name': 'Bob', 'Grades': {'Math': 80, 'Biology': 70, 'Physics': 60}}
# 80

# %%
Student = { "Name" : "Bob",
            "Grades" : {
                "Math" : [80, 75, 90],
                "Biology" : [70, 50, 80, 80, 10],
                "Physics": [60, 75]
                }
        }

print(Student)
print(Student["Grades"]["Math"][2])
# Out:
# {'Name': 'Bob', 'Grades': {'Math': [80, 75, 90], 'Biology': [70, 50, 80, 80, 10], 'Physics': [60, 75]}}
# 90

# %%
print(Student["Grades"]["Biology"][2])
print(Student["Grades"]["Biology"][-1]) # nilai biology terakhir
# Out:
# 80
# 10

# %% [markdown]
# ### Branch

# %%
name = input("Nama: ")
nilai_str = input("Nilai: ")

nilai = float(nilai_str)
if nilai > 90:
    print ("Selamat ",name ,"Lulus dengan nilai diatas rata-rata")
elif nilai > 70:
    print ("Selamat ",name ,"Lulus")
else:
    print ("Anda belum beruntung")
# Out:
# Nama: B
# Nilai: 1000
# Selamat  B Lulus dengan nilai diatas rata-rata

# %% [markdown]
# ### Loop

# %%
for i in range(10):
    print("workshop", i*i)
# Out:
# workshop 0
# workshop 1
# workshop 4
# workshop 9
# workshop 16
# workshop 25
# workshop 36
# workshop 49
# workshop 64
# workshop 81

# %%
name = "workshop"
loop = 10
i = 0
while i < loop:
    print(name, i)
    # i += 1
    i = i + 1
# Out:
# workshop 0
# workshop 1
# workshop 2
# workshop 3
# workshop 4
# workshop 5
# workshop 6
# workshop 7
# workshop 8
# workshop 9

# %% [markdown]
# ### Function

# %%
def calculate_exam_result(name, score):
  if score > 90:
    grade = "Excellent!"
  elif score > 70:
    grade = "Good Job!"
  else:
    grade = "Keep trying!"

  print(f"Hello, {name}! Your score: {score}, {grade}")

# %%
calculate_exam_result("A", 75)
# Out:
# Hello, A! Your score: 75, Good Job!

# %%
calculate_exam_result("B", 95)
# Out:
# Hello, B! Your score: 95, Excellent!

# %%
calculate_exam_result("C", 15)
# Out:
# Hello, C! Your score: 15, Keep trying!

# %%
student_grades = {"A": 75, "B": 95, "C": 15, "D": 0}

# %%
for name, score in student_grades.items():
  calculate_exam_result(name, score)
# Out:
# Hello, A! Your score: 75, Good Job!
# Hello, B! Your score: 95, Excellent!
# Hello, C! Your score: 15, Keep trying!
# Hello, D! Your score: 0, Keep trying!
